# %% [markdown]
# <a href="https://www.kaggle.com/code/sjagkoo7/tensorflow-learning?scriptVersionId=162398231" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # TensorFlow Session Steps :
#    * Importing the desired library
#    * Intializing the variables and constants
#    * Placeholders for performing the compuatation
#    * Intializing a session on CPU or GPU -- no longer required in TensorFlow 2.x
#    * Performing the compuatation
#    * Display results
#    * Close the sessions -- no longer required in TensorFlow 2.x

# %%
# importing tensorflow 
import tensorflow as tf
# Out:
# 2024-02-10 12:27:42.916908: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-10 12:27:42.917051: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-10 12:27:43.080403: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#Intializing the variables and constants
#help(tf.constant)
a=tf.constant([2])
b=tf.constant([3])

# %%
#Placeholders for performing the compuatation
#help(tf.add)
c=tf.add(a,b)
#c=a+b

# %%
# in TensorFlow 2.x , Session is deprecated , now directly evaluate tensors using .numpy() method

#Intializing a session on CPU or GPU
#session=tf.Session()

#Display results
# result=session.run(c)
# print(result)

#Close the sessions
# session.close()

#to avoid close every time using below approach it close session automatically.
# with tf.Session() as session:
#     result=session.run(c)
#     print(result)

# %%
# Display results
print(c.numpy())
# Out:
# [5]
