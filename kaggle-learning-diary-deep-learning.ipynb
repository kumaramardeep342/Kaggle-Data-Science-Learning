# %% [markdown]
# <a href="https://www.kaggle.com/code/sjagkoo7/kaggle-learning-diary-dl-nlp-cv?scriptVersionId=199772786" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# > # 24,25,26,27 -Learning from TensorFlow Basics Example - 1,TensorFlow Basics Example - 2,TensorFlow Linear Regression notebook
# * `Notebook :` https://www.kaggle.com/code/sjagkoo7/tensorflow-basics-example-1
# * `Notebook :` https://www.kaggle.com/code/sjagkoo7/tensorflow-basics-example-2
# * `Notebook :` https://www.kaggle.com/code/sjagkoo7/tensorflow-basics-example-3
# * `Notebook :` https://www.kaggle.com/code/sjagkoo7/tensorflow-linear-regression
# * import tensorflow as tf
# * import tensorflow.compat.v1 as tf # this is for TensorFlow 2.x with eager execution disabled,means we can execute TensorFlow 1.x method like Session etc.
# * tf.disable_eager_execution() # disables eager execution, making TensorFlow operate in graph mode.
# * Scaler , Vector , Matrix , Tensor
# * Constant , Variables , Placeholders
# * Add , matmul , multiply , matrix_determinant
# * reduce_min,reduce_max,reduce_mean,reduce_sum -- min,max,mean and sum
# * one_hot -- one hot endcoding
# > Linear Regression :
#     * cost = tf.reduce_mean(tf.square(pred - Y))  --  mean squared error (MSE)
#     * optimizer = tf.train.GradientDescentOptimizer(learning_rate)  --  minimizing the cost function
#     * train = optimizer.minimize(cost) -- minimize the cost function

# %% [markdown]
# > # 30. Learning from Ed AI _NLP_M1_inclass notebook
# * `Dataset :` https://www.kaggle.com/datasets/dunyajasim/twitter-dataset-for-sentiment-analysis
# * `Notebook :`https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m1-inclass

# %% [markdown]
# > # 31 - 35 . Learning from Ed AI _NLP_M1+M2_inclass, Ed AI _NLP_M1_CaseStudy1, Ed AI _NLP_M1_CaseStudy2, Ed AI _NLP_M2_CaseStudy1, Ed AI _NLP_M2_CaseStudy1  notebook
# * `Dataset :` https://www.kaggle.com/datasets/dunyajasim/twitter-dataset-for-sentiment-analysis
# * `Notebook :`
#     * https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m1-m2-inclass
#     * https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m1-casestudy1
#     * https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m1-casestudy2
#     * https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m2-casestudy1
#     * https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m2-casestudy2
# > **NLTK raw vs. words Method**
# * raw method - macbeth_content = gutenberg.raw('shakespeare-macbeth.txt')
# * words method - macbeth_words = gutenberg.words('shakespeare-macbeth.txt')
# * comaprsion :
#
# ![Screenshot (930).png](attachment:b6580ac5-89e0-4871-a099-30234bc3179d.png)
#
# > **Tokenization** : converting a sequence of text into pieces, or "tokens," which are usually words, phrases, or sentences.
# * **Word Tokenization** : Split the text into words
#
#     `from  nltk.tokenize import word_tokenize
#      tokenized_string = word_tokenize(Text[0])
#      tokenized_string`
# * Regex Tokenization : Find specific text in given text
#
#    `from nltk.tokenize import regexp_tokenize
#     regexp_tokenize(sample_text,pattern = '\d+\.?\d*')`
# * Sentence Tokenization : Split text into sentences
#
#    `from nltk.tokenize import sent_tokenize
#     sent_tokenize(sample_text)`
# * balnkline Tokenization
#
#    `from nltk.tokenize import blankline_tokenize
#     blankline_tokenize(sample_text)`
#
#  > **Stemming** : process of removing suffixes (and sometimes prefixes) from words to return them to their root form, known as the "stem."
# * **PorterStammer** : It uses a series of rules to iteratively reduce words to their stems.
#
#     `from nltk.stem import PorterStemmer # removes 'ies','ied','s','tion','test','ying'
#     pst =  PorterStemmer()
#     print(pst.stem("having"))`
# * **LancasterStemmer** : Known for being more aggressive in its reductions compared
#
#     `from nltk.stem import LancasterStemmer  # removes 'ies','ied','s','tion','test','ying'
#     lst =  LancasterStemmer()
#     print(lst.stem("having"))`
#
# * **SnowBallStemmer** :
#
#     `from nltk.stem import SnowballStemmer  # removes 'ies','ied','s','tion','test','ying'
#     sbt = SnowballStemmer('english')
#     print(sbt.stem("having"))`
#
# > **Lemmatization** : Converts words to their base or dictionary form (lemma) based on the context.Output is proper word.
#
#    `from nltk.stem import wordnet
#     from nltk.stem import WordNetLemmatizer
#     word_lem = WordNetLemmatizer()
#     print(word_lem.lemmatize('corpora'))`

# %% [markdown]
# # 36. Learning from Ed AI _NLP_M2+M3_inclass
# - Notebook :
#     - https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m2-m3-inclass

# %% [markdown]
# # 37-38. Learning From Ed AI _NLP_M4_inclass - ATIS Intent classification ,Ed AI _NLP_ M4_CaseStudy2 - wine-reviews
# - Dataset :
#     - https://www.kaggle.com/datasets/hassanamin/atis-airlinetravelinformationsystem
#     - https://www.kaggle.com/datasets/zynicide/wine-reviews
# - Notebook :
#     - https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m4-inclass-atis-intent-classification
#     - https://www.kaggle.com/code/sjagkoo7/ed-ai-nlp-m4-casestudy2-wine-reviews
# > **Vactorization** :Vectorization is the process of converting data into a vector (a list of numbers).
#
# * Vectorization in Text Processing - CountVectorizer and TF(Term Frequency) & IDF(Inverse Document Frequeny)
#
# * **CountVectorizer** :
#
# `from sklearn.feature_extraction.text import CountVectorizer
# cv= CountVectorizer(ngram_range =(1,1),
#                 stop_words =None,
#                 max_df =1.0,
#                 min_df =1,
#               max_features =None )
# X= cv.fit_transform(df_sliced['Text'])
# pd.DataFrame(X.toarray(),columns=cv.get_feature_names_out())`
#
# * **TF-IDF** :
#     * Term Frequency (TF):
#     TF= (Total number of terms in the document) / (Number of times a term appears in a document)
#     * Inverse Document Frequency (IDF) :
#     IDF=log(Number of documents containing the term / Total number of documents)
#     * TF-IDF Score: The product of TF and IDF.
#         * TF-IDF=TF×IDF
#
# `from sklearn.feature_extraction.text import TfidfVectorizer
# vectorize_tfidf=TfidfVectorizer(stop_words="english",   #stopwords considered as english
#                                 max_df=0.98, #remove a word which repeated 98% in the documents
#                                 min_df=1, # remove a word no repeeation
#                                 max_features=None)
# vectorize_tfidf.fit(df_sliced['Text'])
# X_tfidf=vectorize_tfidf.transform(df_sliced['Text'])
# pd.DataFrame(X_tfidf.toarray(),columns=vectorize_tfidf.get_feature_names_out())`

# %% [markdown]
# # 39-42. Learning From Ed AI _DL_M6_inclass_Classifying handwritten digit ,Ed AI _DL_M6_Case Study_Classifying Images , Ed AI _DL_M7_inclass_Classifying Dog and Cat using ,Ed AI _DL_M7_inclass_Classifying Emotion using CNN
# - Dataset :
#     - https://www.kaggle.com/datasets/deadskull7/fer2013
# - Notebook :
#     - https://www.kaggle.com/code/sjagkoo7/ed-ai-dl-m6-inclass-classifying-handwritten-digit
#     - https://www.kaggle.com/code/sjagkoo7/ed-ai-dl-m6-case-study-classifying-images
#     - https://www.kaggle.com/code/sjagkoo7/ed-ai-dl-m7-inclass-classifying-dog-and-cat-using
#     - https://www.kaggle.com/code/sjagkoo7/ed-ai-dl-m7-inclass-classifying-emotion-using-cnn
# > Activation Function in Neural Networks - Translates inputs to outputs
#
# ![Screenshot (951).png](attachment:eca331bd-68f3-46a3-befa-961956459cd4.png)

# %% [markdown]
# # 44. Learning From Ed AI _DL_M8_inclass_Classifying Dog and Cat using
# - Notebook :
#     - https://www.kaggle.com/code/sjagkoo7/ed-ai-dl-m8-inclass-classifying-dog-and-cat-using#HuggingFace-Pipeline

# %% [markdown]
# # Upcoming Module ....

# %% [markdown]
# # Upcoming exploration ...
# * 20 Newsgroups dataset - from sklearn.datasets import fetch_20newsgroups

# %% [markdown]
# # General

# %% [markdown]
# ## Deep Learning Evolution
# ![Screenshot (1023).png](attachment:0876d962-3d65-4e0a-b44d-ac4ddc09d353.png)</br>
# ![Screenshot (1024).png](attachment:4a56807a-5c7d-4317-b172-8c50d38b8e0b.png)</br>
# ![Screenshot (1025).png](attachment:8cf5bc18-a30e-4764-80da-1116da602614.png)

# %% [markdown]
# ## NLP Evolution
# ![NLP.png](attachment:08e71d11-b559-49c1-82a9-76c5dd890eca.png)

# %% [markdown]
# ## Computer Vision Evolution
# ![DL.png](attachment:a17b23d7-edb2-4cfc-8fca-1478cc442d9d.png)
# ![DL_1.png](attachment:7b6f8e0f-f30c-41d1-8339-6111a2265468.png)

# %% [markdown]
# ## Gen AI Fundation Blocks
# ![Gen AI.png](attachment:efd80660-8d0c-4274-9834-a82f6800c994.png)
